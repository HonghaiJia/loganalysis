# %%
cd E:\\loganalysis\loganalysis
# Out:
# E:\loganalysis\loganalysis

# %%
from loganalysis.lte.ltelog import LteLog

# %%
log = LteLog(r'E:\jiahonghai\bNet_DingQiao_Tau_log\EI_Report\172.16.7.201\EI_Detail\20190422232542')

# %%
log.get_cell_and_ue_ids()
# Out:
#        CellId  UEGID
# 0         206   3751
# 110       204    247
# 126       204   3751
# 521       203   3751
# 1580      205   3751
# 1714      201   3751
# 1848      202   3751
# 0         203    247
# 21443     204   3757
# 21446     204   3755

# %%
cell203 = log.get_cell(203)
# Out:
# Please input uldlcfgidx(0,1,2,7):1

# %%
cell204 = log.get_cell(204)
# Out:
# Please input uldlcfgidx(0,1,2,7):1

# %%
ueIn203 = cell203.get_ue(247)

# %%
ueIn204 = cell204.get_ue(247)

# %%
cell203.show_ue_livetime()

# %%
cell204.show_ue_livetime()

# %%
ueIn203.dl.show_amc()

# %%
ueIn204.dl.show_amc()

# %%
ueIn204.ul.show_amc()
