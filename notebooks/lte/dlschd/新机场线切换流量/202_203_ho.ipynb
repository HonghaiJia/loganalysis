# %%
cd E:\\loganalysis\loganalysis
# Out:
# E:\loganalysis\loganalysis

# %%
from loganalysis.lte.ltelog import LteLog

# %%
log = LteLog(r'E:\jiahonghai\bNet_DingQiao_Tau_log\EI_Report\172.16.7.201\EI_Detail\20190422231114')

# %%
log.describle()
# Out:
#                         size  num_of_files  num_of_lines  pctime_start  \
# filename
# RTL2_ulUeTtiInfo  24812631.0           1.0       52519.0  23:11:15:657
# RTL2_dlUeTtiInfo  52103533.0           3.0      145727.0  23:11:15:657
#
#                     pctime_end  airtime_start   airtime_end
# filename
# RTL2_ulUeTtiInfo  23:12:20:715   2.727340e+09  2.727444e+09
# RTL2_dlUeTtiInfo  23:12:20:715   2.727340e+09  2.727444e+09

# %%
log.get_cell()
# Out:
# '所有CellId：{201, 202, 203, 204, 205, 206}. 请使用get_cell(cellid)获取对应的Cell实例'

# %%
log.get_cell_and_ue_ids()
# Out:
#        CellId  UEGID
# 0         205   3751
# 123       206   3751
# 261       203    247
# 265       203   3751
# 775       202   3751
# 0         202    247
# 1409      201   3751
# 1539      204   3751
# 33317     203   3757
# 33322     203   3755
# 33323     203   3916

# %%
cell203 = log.get_cell(203)
# Out:
# Please input uldlcfgidx(0,1,2,7):1

# %%
cell202 = log.get_cell(202)
# Out:
# Please input uldlcfgidx(0,1,2,7):1

# %%
ueIn203 = cell203.get_ue(247)

# %%
ueIn202 = cell202.get_ue(247)

# %%
cell203.show_ue_livetime()

# %%
cell202.show_ue_livetime()

# %%
ueIn203.dl.show_amc()

# %%
ueIn202.dl.show_amc()

# %%
ueIn202.ul.show_amc()

# %%
ueIn203.ul.show_amc()

# %%
ueIn202.ul.show_amc()
