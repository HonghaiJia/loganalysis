# %%
cd E:\\loganalysis\loganalysis
# Out:
# E:\loganalysis\loganalysis

# %%
from loganalysis.lte.ltelog import LteLog

# %%
log = LteLog(r'E:\jiahonghai\bNet_DingQiao_Tau_log\EI_Report\172.16.7.201\EI_Detail\20190422232031')

# %%
log.get_cell_and_ue_ids()
# Out:
#        CellId  UEGID
# 0         201    247
# 1         201   3751
# 204       202   3751
# 334       204   3751
# 464       206   3751
# 602       205   3751
# 1358      203   3751
# 1452      203    247
# 20040     203   3757
# 20043     203   3755
# 21131     201   3757
# 21134     201   3755
# 26257     203   3807

# %%
cell203 = log.get_cell(203)
# Out:
# Please input uldlcfgidx(0,1,2,7):1

# %%
cell201 = log.get_cell(201)
# Out:
# Please input uldlcfgidx(0,1,2,7):1

# %%
ueIn203 = cell203.get_ue(247)

# %%
ueIn201 = cell201.get_ue(247)

# %%
cell203.show_ue_livetime()

# %%
cell201.show_ue_livetime()

# %%
ueIn203.dl.show_amc()

# %%
ueIn201.dl.show_amc()

# %%
ueIn201.ul.show_amc()

# %%
ueIn203.ul.show_amc()

# %%
ueIn201.ul.show_amc()
