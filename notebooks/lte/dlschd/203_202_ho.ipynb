# %%
cd E:\\loganalysis\loganalysis
# Out:
# E:\loganalysis\loganalysis

# %%
from loganalysis.lte.ltelog import LteLog

# %%
log = LteLog(r'E:\jiahonghai\bNet_DingQiao_Tau_log\EI_Report\172.16.7.201\EI_Detail\20190422230711')

# %%
log.describle()
# Out:
#                         size  num_of_files  num_of_lines  pctime_start  \
# filename
# RTL2_ulUeTtiInfo  23957603.0           1.0       50686.0  23: 7:12:486
# RTL2_dlUeTtiInfo  45430951.0           2.0      126866.0  23: 7:12:486
#
#                     pctime_end  airtime_start   airtime_end
# filename
# RTL2_ulUeTtiInfo  23: 8:14:685   2.726951e+09  2.727051e+09
# RTL2_dlUeTtiInfo  23: 8:14:653   2.726951e+09  2.727051e+09

# %%
log.get_cell()
# Out:
# '所有CellId：{201, 202, 203, 204, 205, 206}. 请使用get_cell(cellid)获取对应的Cell实例'

# %%
log.get_cell_and_ue_ids()
# Out:
#        CellId  UEGID
# 0         203    247
# 1         203   3751
# 1176      201   3751
# 1310      204   3751
# 1444      202   3751
# 1578      205   3751
# 1712      206   3751
# 33941     202    247
# 40453     202   3757
# 40456     202   3755

# %%
cell203 = log.get_cell(203)
# Out:
# Please input uldlcfgidx(0,1,2,7):1

# %%
cell202 = log.get_cell(202)

# %%
ueIn203 = cell203.get_ue(247)

# %%
ueIn202 = cell202.get_ue(247)

# %%
cell203.show_ue_livetime()

# %%
cell202.show_ue_livetime()

# %%
ueIn203.dl.show_amc()

# %%
ueIn202.dl.show_amc()

# %%
ueIn202.ul.show_amc()

# %%
ueIn203.ul.show_amc()
