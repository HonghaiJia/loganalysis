# %%
cd E:\\loganalysis\loganalysis
# Out:
# E:\loganalysis\loganalysis

# %%
from loganalysis.lte.ltelog import LteLog

# %%
log = LteLog(r'E:\jiahonghai\bNet_DingQiao_Tau_log\EI_Report\172.16.7.201\EI_Detail\20190422231433')

# %%
log.describle()
# Out:
#                          size  num_of_files  num_of_lines  pctime_start  \
# filename
# RTL2_ulUeTtiInfo   74203163.0           3.0      157291.0  23:14:34:675
# RTL2_dlUeTtiInfo  142230528.0           6.0      396599.0  23:14:34:675
#
#                     pctime_end  airtime_start   airtime_end
# filename
# RTL2_ulUeTtiInfo   23:17:49:86   2.727658e+09  2.727970e+09
# RTL2_dlUeTtiInfo  23:17:49:117   2.727658e+09  2.727970e+09

# %%
log.get_cell()
# Out:
# '所有CellId：{201, 202, 203, 204, 205, 206}. 请使用get_cell(cellid)获取对应的Cell实例'

# %%
log.get_cell_and_ue_ids()
# Out:
#        CellId  UEGID
# 0         203    247
# 16        203   3751
# 1540      201   3751
# 1670      205   3751
# 1800      202   3751
# 1930      204   3751
# 2060      206   3751
# 12627     201    247
# 29514     201   3757
# 29517     201   3755
# 31573     203   3757
# 31576     203   3755

# %%
cell203 = log.get_cell(203)
# Out:
# Please input uldlcfgidx(0,1,2,7):1

# %%
cell201 = log.get_cell(201)
# Out:
# Please input uldlcfgidx(0,1,2,7):1

# %%
ueIn203 = cell203.get_ue(247)

# %%
ueIn201 = cell201.get_ue(247)

# %%
cell203.show_ue_livetime()

# %%
cell201.show_ue_livetime()

# %%
ueIn203.dl.show_amc()

# %%
ueIn201.dl.show_amc()

# %%
ueIn201.ul.show_amc()

# %%
ueIn203.ul.show_amc()

# %%
ueIn201.ul.show_amc()
