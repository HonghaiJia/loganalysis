# %%
cd E:\\loganalysis\loganalysis
# Out:
# E:\loganalysis\loganalysis

# %%
from loganalysis.lte.ltelog import LteLog

# %%
log = LteLog(r'E:\jiahonghai\bNet_DingQiao_Tau_log\EI_Report\172.16.7.201\EI_Detail\20190422232631')

# %%
log.get_cell_and_ue_ids()
# Out:
#        CellId  UEGID
# 0         204    247
# 2         204   3751
# 920       205   3751
# 1052      202   3751
# 1184      201   3751
# 1316      206   3751
# 1456      203   3751
# 26452     206    247
# 34302     206   3757
# 34307     206   3755
# 34308     206   3797

# %%
cell206 = log.get_cell(206)
# Out:
# Please input uldlcfgidx(0,1,2,7):1

# %%
cell204 = log.get_cell(204)
# Out:
# Please input uldlcfgidx(0,1,2,7):1

# %%
ueIn206 = cell206.get_ue(247)

# %%
ueIn204 = cell204.get_ue(247)

# %%
cell206.show_ue_livetime()

# %%
cell204.show_ue_livetime()

# %%
ueIn206.dl.show_amc()

# %%
ueIn204.dl.show_amc()

# %%
ueIn204.ul.show_amc()

# %%
ueIn206.ul.show_amc()
