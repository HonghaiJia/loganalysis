# %%
cd E:\\loganalysis\loganalysis
# Out:
# E:\loganalysis\loganalysis

# %%
from loganalysis.lte.ltelog import LteLog

# %%
log = LteLog(r'E:\jiahonghai\bNet_DingQiao_Tau_log\EI_Report\172.16.7.201\EI_Detail\20190422232740')

# %%
log.get_cell_and_ue_ids()
# Out:
#        CellId  UEGID
# 0         206    247
# 16        206   3751
# 1623      205   3751
# 1755      201   3751
# 1887      204   3751
# 2019      202   3751
# 2151      203   3751
# 33088     206   3752
# 33220     204   3752
# 33352     201   3752
# 33486     205   3752
# 33618     202   3752
# 33750     203   3752
# 35392     206    248
# 11423     206   3757
# 11426     206   3755

# %%
cell206 = log.get_cell(206)
# Out:
# Please input uldlcfgidx(0,1,2,7):1

# %%
cell204 = log.get_cell(204)
# Out:
# Please input uldlcfgidx(0,1,2,7):1

# %%
ueIn206 = cell206.get_ue(247)

# %%
ueIn204 = cell206.get_ue(248)

# %%
cell206.show_ue_livetime()

# %%
cell204.show_ue_livetime()

# %%
ueIn206.dl.show_amc()

# %%
ueIn204.dl.show_amc()

# %%
ueIn204.ul.show_amc()

# %%
ueIn206.ul.show_amc()
