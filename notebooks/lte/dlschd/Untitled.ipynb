# %%
cd E:\\rtl2master\loganalysis
# Out:
# E:\rtl2master\loganalysis

# %%
from loganalysis.lte.ltelog import LteLog

# %%
log = LteLog(r'E:\jiahonghai')

# %%
log.describle()
# Out:
#                         size  num_of_files  num_of_lines  pctime_start  \
# filename
# RTL2_dlUeTtiInfo  24450357.0           1.0       69502.0   5:41:49:226
#
#                     pctime_end  airtime_start   airtime_end
# filename
# RTL2_dlUeTtiInfo   5:42:35:820   4.156755e+09  4.156829e+09

# %%
cell = log.get_cell()

# %%
cell
# Out:
# '所有CellId：{112}. 请使用get_cell(cellid)获取对应的Cell实例'

# %%
cell = log.get_cell(112)

# %%
cell.get_ue()
# Out:
# '所有UEGID：{3751, 41, 3754, 245, 246, 247, 248, 249}. 请使用get_ue(uegid)获取对应的UE实例'

# %%
ue = cell.get_ue(41)

# %%
ue.dl.find_harqfail()
# Out:
# Empty DataFrame
# Columns: [ACK.u32DemTime, UEGID, ACK.u8HarqId, ACK.u8Tb0IsHarqFail, ACK.u8Tb1IsHarqFail]
# Index: []

# %%
ue.dl.show_bler_of_subframe()

# %%
ue.dl.show_schd_uecnt()

# %%
ue.dl.schdfail_reasons()
# Out:
# Fail_Rsn
# has_schded    1648.0
# dtype: float64

# %%
ue.dl.show_amc()

# %%
cell.show_ue_livetime()

# %%
ue.dl.show_bler_of_subframe(subframe=2)

# %%
ue.dl.show_bler_of_subframe(subframe=7)

# %%
ue.dl.show_bler_of_subframe(subframe=3)

# %%
ue.dl.show_bler_of_subframe(subframe=8)

# %%
sib = cell.get_ue(3751)

# %%
sib.dl.show_schd_rbnum()

# %%
sib.dl.show_schd_uecnt()
