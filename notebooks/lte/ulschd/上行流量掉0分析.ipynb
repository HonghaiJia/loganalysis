# %%
cd F:\jiahonghai\loganalysis\loganalysis
# Out:
# F:\jiahonghai\loganalysis\loganalysis

# %%
from loganalysis.lte.ltelog import LteLog

# %%
log = LteLog(r'F:\jiahonghai\airlinelog')

# %%
log.get_cell_and_ue_ids()
# Out:
#        CellId  UEGID
# 0         201    332
# 1         201   3751
# 59        203   3751
# 461       204   3751
# 587       206   3751
# 851       205   3751
# 0         203    332
# 77512     201   3754
# 23922     201   3757
# 23925     201   3755
# 56029     201   3829
# 56030     201   3820
# 56060     201   3825
# 56061     201   3899
# 56090     201   3810
# 56115     201   3837
# 56300     201   3902

# %%
cell201 = log.get_cell(201)
# Out:
# Please input uldlcfgidx(0,1,2,7):1

# %%
ue332 = cell201.get_ue(332)

# %%
# %matplotlib notebook

# %%
ue332.ul.show_schd_uecnt()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ue332.ul.show_schd_rbnum()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ue332.ul.show_amc()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %pdb
# Out:
# Automatic pdb calling has been turned ON

# %%
rlt = ue332.ul.show_throuput()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ue332.dl.show_throuput()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ta = ue332.dl.show_ta()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
log.show_ue_livetime()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-54b0cb3c6c89> in <module>
# ----> 1 log.show_ue_livetime()
#
# F:\jiahonghai\loganalysis\loganalysis\loganalysis\lte\ltelog.py in show_ue_livetime(self)
#     156
#     157         rlt = pd.DataFrame()
# --> 158         for data in self.gen_of_cols(cols):
#     159             data = data.groupby((cols[1], cols[2]))
#     160             start = data[cols[0]].first()
#
# AttributeError: 'LteLog' object has no attribute 'gen_of_cols'
# > f:\jiahonghai\loganalysis\loganalysis\loganalysis\lte\ltelog.py(158)show_ue_livetime()
#     156
#     157         rlt = pd.DataFrame()
# --> 158         for data in self.gen_of_cols(cols):
#     159             data = data.groupby((cols[1], cols[2]))
#     160             start = data[cols[0]].first()
