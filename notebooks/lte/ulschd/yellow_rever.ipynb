# %%
cd F:\jiahonghai\loganalysis\loganalysis
# Out:
# F:\jiahonghai\loganalysis\loganalysis

# %%
from loganalysis.lte.ltelog import LteLog

# %%
log = LteLog(r'F:\jiahonghai\yellow_reiver')

# %%
log.describle()
# Out:
#                        size  num_of_files  num_of_lines  pctime_start  \
# filename
# RTL2_ulUeTtiInfo  5109315.0           1.0       17683.0  14:49:28:600
# RTL2_dlUeTtiInfo  7943683.0           1.0       34292.0  14:45:52:549
#
#                     pctime_end  airtime_start   airtime_end
# filename
# RTL2_ulUeTtiInfo  14:49:38:670   1.425477e+09  1.425494e+09
# RTL2_dlUeTtiInfo  14:46:15:806   1.425131e+09  1.425170e+09

# %%
log.get_cell_and_ue_ids()
# Out:
#     CellId  UEGID
# 0        1     30
# 2        1     11
# 6        1   3751
# 12       1     10
# 13       1     40

# %%
cell = log.get_cell(1)
# Out:
# Please input uldlcfgidx(0,1,2,7):0

# %%
cell.show_ue_livetime()

# %%
ue = cell.get_ue(30)

# %%
# %matplotlib notebook

# %%
ue.ul.show_schd_uecnt()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ue.ul.show_schd_rbnum()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ue.ul.show_amc()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ue.ul.show_harqfail_cnt()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ue.ul.show_rpt_minbsr()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ue.ul.show_1rbsinr()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ue.ul.show_pathloss()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ue.ul.find_harqfail()
# Out:
# Empty DataFrame
# Columns: [UEGID, CRCI.u32DemTime, CRCI.u8CrcHarqId, CRCI.b8IsHarqFail]
# Index: []

# %%
ue.ul.show_schd_mcs()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ue.dl.show_amc_txdiv()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ue.dl.show_schd_uecnt()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ue.dl.show_throuput()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ue.dl.show_dtx_cnt()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ue.ul.show_dci0lost_cnt()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ue.dl.show_ta()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ue.dl.show_harqfail_cnt()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ue.ul.show_dci0lost_cnt()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ue.dl.show_amc_cdd()
# Out:
# No Data to analysis of columns: [AMC_CDD.s16CddDeltaMcs, AMC_CDD.u8CddStdMcs]

# %%
# Out:
# Automatic pdb calling has been turned ON
