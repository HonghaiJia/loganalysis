# %%
cd F:\jiahonghai\loganalysis\loganalysis

# %%
from loganalysis.lte.ltelog import LteLog

# %%
log = LteLog(r'F:\jiahonghai\airlinelog')

# %%
log.get_cell_and_ue_ids()
# Out:
#        CellId  UEGID
# 0         201    332
# 1         201   3751
# 59        203   3751
# 461       204   3751
# 587       206   3751
# 851       205   3751
# 0         203    332
# 77512     201   3754
# 23922     201   3757
# 23925     201   3755
# 56029     201   3829
# 56030     201   3820
# 56060     201   3825
# 56061     201   3899
# 56090     201   3810
# 56115     201   3837
# 56300     201   3902

# %%
log._cell_and_ue_ids
# Out:
#        CellId  UEGID
# 0         201    332
# 1         201   3751
# 59        203   3751
# 461       204   3751
# 587       206   3751
# 851       205   3751
# 0         203    332
# 77512     201   3754
# 23922     201   3757
# 23925     201   3755
# 56029     201   3829
# 56030     201   3820
# 56060     201   3825
# 56061     201   3899
# 56090     201   3810
# 56115     201   3837
# 56300     201   3902

# %%
ue332 = log.get_ue(332)

# %%
ue332.dl.show_ta()

# %%
ue332.dl.show_amc()

# %%
log.show_ue_livetime()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-54b0cb3c6c89> in <module>
# ----> 1 log.show_ue_livetime()
#
# F:\jiahonghai\loganalysis\loganalysis\loganalysis\lte\ltelog.py in show_ue_livetime(self)
#     156
#     157         rlt = pd.DataFrame()
# --> 158         for data in self.gen_of_cols(cols):
#     159             data = data.groupby((cols[1], cols[2]))
#     160             start = data[cols[0]].first()
#
# AttributeError: 'LteLog' object has no attribute 'gen_of_cols'

# %%
cell201 = log.get_cell(201)
# Out:
# Please input uldlcfgidx(0,1,2,7):1

# %%
cell201.dl.show_schd_rbnum()

# %%
ue=cell201.get_ue(332)

# %%
ue.ul.show_schd_uecnt()

# %%
cell201._dllog.set_airtimes_interval(3551246774, 3552307237)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-769e2f909a2f> in <module>
# ----> 1 cell201._dllog.set_airtimes_interval(3551246774, 3552307237)
#
# AttributeError: 'Cell' object has no attribute '_dllog'

# %%
ue332.dl.show_schd_rbnum()

# %%
ue332._dllog.reset_airtimes_interval()

# %%
ue332.dl.show_schd_rbnum()

# %%
cell201.show_ue_livetime()
